# %%
#Loading the necessary libraries
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
#Loading the data
df = sns.load_dataset('titanic')
df1 = sns.load_dataset('iris')
df2 = sns.load_dataset('tips')
df3 = sns.load_dataset("mpg")

# %% [markdown]
# #### Univariate(Only one Feature)
#
#     Box Plot
#     Violin Plot
#     Distribution Plot
#     Joint Plot

# %% [markdown]
# Boxplot used to obtain stastical details about the data \
# Used for checking Outliers \
# Interquaratile Range(IQR) --> where maximum data details of the data is present \
# For checking influenc of the a single independent varaible and a dependent variable

# %%
plt.boxplot(df['fare'])
df2.boxplot(by = 'day',column=['total_bill'],grid=False)
# Out:
# <AxesSubplot:title={'center':'total_bill'}, xlabel='day'>

# %%
sns.boxplot(x=df1["species"], y=df1["sepal_length"])
# Out:
# <AxesSubplot:xlabel='species', ylabel='sepal_length'>

# %% [markdown]
# Violinplot is the combination of boxplot at the middle and KDE(Kernal Density Estimation) distibution plot on both sides of the data \
# Can provide details of distribution like whether the distribution has multimodal,skewness,etc \
# Also provides a 95% confidence interval

# %%
sns.violinplot(x='day',y ='total_bill',data = df2)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %% [markdown]
# Displot is the best univaraite plot to know about the distribution of data(Combination of Probability density function and histogram in a single figure) \
# Probability density function is used for finding the underlying distribution of the feature(EDA)

# %%
sns.displot(data=df,x ='age',hue='survived',kde = True)

# %% [markdown]
# Jointplot is used for both univariate and bivariate analysis \
# Top and right side provides the univariate analysis of the considered features

# %%
sns.jointplot(x = "mpg", y = "acceleration",kind = "scatter", data = df3)

# %% [markdown]
# #### Bivariate(Two Features)
#
#     Scatter Plot
#     Joint Plot
#     Bar Plot
#     Line Plot

# %% [markdown]
# Scatter plot is the most convenient way to visualize the distribution where each observation is represented in two -dimensional plot via x and y axis

# %%
plt.scatter(x = df1['sepal_length'],y = df1['petal_length'])
plt.xlabel('Sepal Length')
plt.ylabel('Petal Length')
# Out:
# Text(0, 0.5, 'Petal Length')

# %%
sns.scatterplot(x="sepal_length", y="petal_length", hue = 'species', data=df1)
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>

# %% [markdown]
# Jointplot is used for both univariate and bivariate analysis \
# Top and right side provides the univariate analysis of the considered features

# %% [markdown]
# Barplot shows the relationship between a numeric and a categoric variable\
# Each entity of the categoric variable is represented as a bar. The size of the bar represents its numeric value

# %%
sns.barplot(x = 'time',y = 'total_bill',data = df2)
# Out:
# <AxesSubplot:xlabel='time', ylabel='total_bill'>

# %% [markdown]
# Line plot is a sort of graph that shows how data evolves and created by connecting several points with straight lines

# %%
sns.lineplot(x='size', y='tip', data=df2)
# Out:
# <AxesSubplot:xlabel='size', ylabel='tip'>

# %% [markdown]
# #### Multivariate(Many Features)
#
#     Pair Plot

# %% [markdown]
# Pairplot is the combination of all available features in the dataset \
# Gets complex if more than 10 features

# %%
sns.pairplot(data=df1,hue ='species')

# %% [markdown]
# Above data are just for extracting useful insights/information of the data

# %% [markdown]
# #### But the real Inference/Final Information is obtained through Heatmap

# %%
correlation = df1.corr()
sns.heatmap(correlation,cmap='cubehelix',annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### Others
#
#     WordCloud
#     Graphviz
#     Dendograms
